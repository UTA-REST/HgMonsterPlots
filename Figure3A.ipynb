# %%
import pylab
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
dat=pd.read_excel("Data/Fig3.xlsx")
dat
# Out:
#         6A  Unnamed: 1     6B  Unnamed: 3     6C  Unnamed: 5
# 0    252.0    0.334169  252.0    0.634804  260.0    0.841915
# 1    253.0    0.352700  253.0    0.638448  261.0    0.843601
# 2    254.0    0.371260  254.0    0.640280  262.0    0.840717
# 3    255.0    0.385999  255.0    0.637490  263.0    0.819807
# 4    256.0    0.405444  256.0    0.632371  264.0    0.808449
# ..     ...         ...    ...         ...    ...         ...
# 493    NaN         NaN  745.0    0.004647    NaN         NaN
# 494    NaN         NaN  746.0    0.004645    NaN         NaN
# 495    NaN         NaN  747.0    0.004683    NaN         NaN
# 496    NaN         NaN  748.0    0.004986    NaN         NaN
# 497    NaN         NaN  749.0    0.005335    NaN         NaN
#
# [498 rows x 6 columns]

# %%
x1 = list(dat['6A'])
x2 =list(dat['6B'])
x3 = list(dat['6C'])
y1 = list(dat['Unnamed: 1'])
y2 = list(dat['Unnamed: 3'])
y3 = list(dat['Unnamed: 5'])

# %%
#a1 = mpatches.Patch(facecolor='#ff0000', label='$\mathregular{Hg^{+}}$', linewidth = 0.5, edgecolor = 'black')
#a2 = mpatches.Patch(facecolor='#ff8000', label = '$\mathregular{K^{+}}$', linewidth = 0.5, edgecolor = 'black')
#a3 = mpatches.Patch(facecolor='#FFC600', label='$\mathregular{Cs^{+2}}$', linewidth = 0.5, edgecolor = 'black')

# %%
plt.figure(figsize=(5,5),dpi=200)
plt.plot(x1,y1,color='black')
plt.plot(x2,y2,color='DarkRed')
plt.plot(x3,y3,color="DarkBlue")

pylab.ylim(0,0.8)
pylab.xlim(250,750)
pylab.xlabel("Wavelength (nm)")
pylab.ylabel("Fluorescene Intensity (arb)")
pylab.legend(['1A','1B','1C'],loc='upper right')
ax = plt.gcf().gca()
plt.tight_layout()
plt.savefig('Figs/Figure3A.png',bbox_inches='tight')
plt.show()
