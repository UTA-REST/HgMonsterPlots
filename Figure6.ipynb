# %%
import pylab
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
dat=pd.read_excel("Data/EtOHMetalsisolated.xlsx")
dat
# Out:
#     Sample      I-Ioff
# 0    crown    0.000000
# 1       Hg  298.058411
# 2       Ag   -2.030579
# 3       Ba    1.627870
# 4       Ca    0.003927
# 5       Cd    1.571374
# 6       Cs    3.247993
# 7       Cu   30.859713
# 8        K    1.126558
# 9       Li   -1.597977
# 10      Me    3.391785
# 11      Mg   -3.151835
# 12      Na    2.649776
# 13      Pb   17.240772
# 14      Rb    2.295748
# 15      Zn    3.728233
# 16  crownw    0.000000
# 17      Hg    0.000000
# 18   Ag+Hg  268.000916
# 19   Ba+Hg  265.295227
# 20   Ca+Hg  283.990631
# 21   Cd+Hg  280.840210
# 22   Cs+Hg  265.877975
# 23   Cu+Hg  277.072479
# 24    K+Hg  261.595612
# 25   Li+Hg  259.249832
# 26   Me+Hg  282.667175
# 27   Mg+Hg  282.454971
# 28   Na+Hg  283.713409
# 29   Pb+Hg  274.138168
# 30   Rb+Hg  242.750931
# 31   Zn+Hg  283.254242

# %%
#x = ['crown','Hg','Ag','Ba','Ca','Cd','Cs','Cu','K','Li','Me','Mg','Na','Pb','Rb','Zn']
#y = [0,298.0584107,-2.030578615,1.627869605,0.00392723,1.571373935,3.247993465,30.8597126,1.126558305,-1.597976685,3.39178467,-3.15183544,2.64977646,17.24077225,2.29574776,3.728233335]
#y2= [0,0,268.0009155,265.2952271,283.9906311,280.84021,265.8779755,277.0724792,261.5956116,259.2498322,282.6671753,282.4549713,283.7134094,274.1381684,242.7509308,283.2542419]
#x2 = ['crownw','Hg',Ag+Hg','Ba+Hg','Ca+Hg','Cd+Hg','Cs+Hg','Cu+Hg','K+Hg','Li+Hg','Me+Hg','Mg+Hg','Na+Hg','Pb+Hg','Rb+Hg','Zn+Hg']

# %%
order=[0,10,3,6,14,13,4,2,12,8,11,7,1,5,9]

withHg    = np.array([0,268.0009155,265.2952271,283.9906311,280.84021,265.8779755,277.0724792,261.5956116,259.2498322,282.6671753,282.4549713,283.7134094,274.1381684,242.7509308,283.2542419])
withoutHg = np.array([298.0584107,-2.030578615,1.627869605,0.00392723,1.571373935,3.247993465,30.8597126,1.126558305,-1.597976685,3.39178467,-3.15183544,2.64977646,17.24077225,2.29574776,3.728233335])
labels    = np.array(['Hg$^{2+}$','Ag$^+$','Ba$^{2+}$','Ca$^{2+}$','Cd$^{2+}$','Cs$^{+}$','Cu$^{2+}$','K$^{+}$','Li$^+$','NMe$_{4}^{+}$','Mg$^{2+}$','Na$^{+}$','Pb$^{2+}$','Rb$^{2+}$','Zn$^{2+}$'])
n=15
r = np.arange(len(order))
width = 0.25

plt.figure(figsize=(8,4),dpi=200)
#plt.grid(axis='y')
plt.bar(r[1:]-width, withoutHg[order][1:], color = 'blue',
        width = width, edgecolor = 'black',
        label='1B + Analyte')
plt.bar(r[1:], withHg[order][1:], color = 'skyblue',
        width = width, edgecolor = 'black',
        label='1B + Analyte + Hg$^{2+}$')
plt.bar(r[0], withoutHg[order][0], color = 'blue',
        width = width, edgecolor = 'black')


plt.ylabel("I - $\mathregular{I_{o}}$ ")
plt.ylim(0,380)
  
plt.xticks(r,labels[order],rotation=90,fontsize=12,va='bottom')
plt.tick_params(axis='x', which='major', pad=35)
plt.plot([8.5,8.5],[0,380],':',color='black',linewidth=1)
plt.plot([13.5,13.5],[0,380],':',color='black',linewidth=1)
plt.legend(loc='upper right', framealpha=1)
plt.tight_layout()
plt.savefig('Figs/Figure6.png',bbox_inches='tight')  
plt.xlim(-0.5,14.5)
plt.show()
