# %%
import pylab
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
dat=pd.read_excel("Data/Solvents_Isolated.xlsx")
dat
# Out:
#      Wavelength (nm)      DMSO      MeOH       DCM      EtOH       THF  \
# 0         800.004761 -0.027488 -0.023967 -0.026321 -0.024274 -0.023577
# 1         799.032959 -0.026861 -0.022718 -0.026804 -0.023785 -0.025487
# 2         798.060791 -0.027090 -0.022855 -0.026556 -0.023433 -0.026597
# 3         796.949280 -0.026855 -0.023317 -0.026481 -0.022951 -0.025627
# 4         795.976318 -0.026413 -0.022333 -0.026967 -0.025004 -0.024741
# ..               ...       ...       ...       ...       ...       ...
# 596       203.921982  3.168724  0.569776  2.997320       NaN  3.154542
# 597       202.978394  3.423961  0.678419  3.194062       NaN  3.084803
# 598       202.034729  3.483241  0.752979  2.958288       NaN  3.064998
# 599       200.933701  3.403361  0.865009  3.192967       NaN  3.054983
# 600       199.989761  3.552838  1.043034  3.111615       NaN  2.930979
#
#      Wavelength EtOH
# 0         800.004761
# 1         795.002991
# 2         789.991211
# 3         784.969604
# 4         779.938232
# ..               ...
# 596              NaN
# 597              NaN
# 598              NaN
# 599              NaN
# 600              NaN
#
# [601 rows x 7 columns]

# %%
x = list(dat['Wavelength (nm)'])
x2 = list(dat['Wavelength EtOH'])
y1 = list(dat['DMSO'])
y2 = list(dat['MeOH'])
y3 = list(dat['DCM'])
y4 = list(dat['EtOH'])
y5 = list(dat['THF'])

# %%
a1 = mpatches.Patch(facecolor='red', label='DMSO', linewidth = 0.5, edgecolor = 'black')
a2 = mpatches.Patch(facecolor='blue', label = 'MeOH', linewidth = 0.5, edgecolor = 'black')
a3 = mpatches.Patch(facecolor='green', label = 'DCM', linewidth = 0.5, edgecolor = 'black')
a4 = mpatches.Patch(facecolor='purple', label = 'EtOH', linewidth = 0.5, edgecolor = 'black')
a5 = mpatches.Patch(facecolor='orange', label = 'THF', linewidth = 0.5, edgecolor = 'black')

# %%
plt.figure(figsize=(5,5),dpi=200)
plt.plot(x,y1,color='red')
plt.plot(x,y2,color='blue')
plt.plot(x,y3,color='green')
plt.plot(x2,y4,color='purple')
plt.plot(x,y5,color='orange')
pylab.ylim(0,0.14)
pylab.xlim(350,600)
pylab.xlabel("Wavelength (nm)")
pylab.ylabel("Fluorescene Intensity (arb)")
pylab.legend(handles=[a1,a2,a3,a4,a5],loc='upper right') 
plt.tight_layout()
plt.savefig('Figs/Figure6.png',bbox_inches='tight')
plt.show()
